# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import requests
import os
import zipfile, io

# %%
df1 = pd.read_csv('C:\Users\Neha\Desktop\Neha\MERGED2017_18_PP.csv', low_memory = False)

# %%
ax = sb.regplot(x="ADM_RATE_ALL", y="AVGFACSAL", data=df1, fit_reg = False)
plt.title('Admission Rate  Avg. Faculty Salary', fontsize = 12)
# Out:
# Text(0.5,1,'Admission Rate  Avg. Faculty Salary')

# %%
sb.boxplot(data = df1, x = 'DISTANCEONLY', y = 'AVGFACSAL')
plt.title('Distance Education and Faculty Salary', fontsize = 15)
plt.ylabel('Average Faculty Salary', fontsize = 13)
plt.xlabel('Type of education', fontsize = 14);
